# %%
# Get imports from imports.py
# Will try to pull imports from ./../modules/
from imports import *

# %%
# Define root directory for data.. 

# Expects a data directory with the following structure:
# rootdir/galaxy/hst/ - contains the HST data
# rootdir/galaxy/hst_contsub/ - contains the reduced Halpha data
# rootdir/galaxy/muse/ - contains the muse data

rootdir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/'

# %%
galaxy = 'ic5332' # Name of the galaxy
filters = ['f658n', 'f555w', 'f814w'] # Filters used in the HST data
instruments = ['uvis', 'uvis', 'uvis'] # Instruments used in the HST data

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc628c'
galaxy_muse = 'ngc0628'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['acs', 'acs', 'acs']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments, galaxy_muse=galaxy_muse) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_all=True) # Save the HDU files

# %%
galaxy = 'ngc628e'
galaxy_muse = 'ngc0628'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'acs']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments, galaxy_muse=galaxy_muse) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc1087'
filters = ['f657n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc1300'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['acs', 'acs', 'acs']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc1365n'
galaxy_muse = 'ngc1365'
filters = ['f657n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments, galaxy_muse=galaxy_muse) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc1385'
filters = ['f657n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc1433'
filters = ['f657n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc1512'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc1566'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc1672'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['acs', 'uvis', 'acs']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc2835'
galaxy_muse = 'ngc2835'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments, galaxy_muse=galaxy_muse) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst/ngc2835_uvis_f658n_exp_drc_sci.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst/ngc2835s_uvis_f555w_exp_drc_sci.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst/ngc2835s_uvis_f814w_exp_drc_sci.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/muse/NGC2835-1.15asec_UVIS_F658N.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/muse/NGC2835-1.15asec_UVIS_F555W.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/muse/NGC2835-1.15asec_UVIS_F814W.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/muse/NGC2835_starmask.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/muse/NGC2835_nebmask.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/muse/NGC2835-1.15asec_MAPS.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst/ngc2835_uvis_f658n_err_drc_wht.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst/ngc2835s_uvis_f555w_err_drc_wht.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst/ngc2835s_uvis_f814w_err_drc_wht.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_ACS_WFC.F550M.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_ACS_WFC.F555W.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_ACS_WFC.F658N.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_ACS_WFC.F814W.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_WFC3_UVIS1.F555W.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_WFC3_UVIS1.F657N.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_WFC3_UVIS1.F658N.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_WFC3_UVIS1.F814W.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_WFC3_UVIS2.F547M.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_WFC3_UVIS2.F555W.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_WFC3_UVIS2.F657N.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_WFC3_UVIS2.F658N.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_WFC3_UVIS2.F673N.dat
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/hst_filters/HST_WFC3_UVIS2.F814W.dat
# [INFO] Remove NaN values around edge of image...
# [INFO] Reprojecting the input image to match the template WCS...
# [INFO] Performing image reprojection...
# [INFO] Image reprojection complete.
# [INFO] Scaling the output data to conserve flux with factor 1.00
# [INFO] Flux scaling complete.
# [INFO] Reprojection process completed.
# [INFO] Reprojecting the input image to match the template WCS...
# [INFO] Performing image reprojection...
# [INFO] Image reprojection complete.
# [INFO] Scaling the output data to conserve flux with factor 1.00
# [INFO] Flux scaling complete.
# [INFO] Reprojection process completed.
# [INFO] Reprojecting the input image to match the template WCS...
# [INFO] Performing image reprojection...
# [INFO] Image reprojection complete.
# [INFO] Scaling the output data to conserve flux with factor 1.00
# [INFO] Flux scaling complete.
# [INFO] Reprojection process completed.
# [INFO] Reprojecting the input image to match the template WCS...
# [INFO] Performing image reprojection...
# [INFO] Image reprojection complete.
# [INFO] Scaling the output data to conserve flux with factor 1.00
# [INFO] Flux scaling complete.
# [INFO] Reprojection process completed.
# [INFO] Reprojecting the input image to match the template WCS...
# [INFO] Performing image reprojection...
# [INFO] Image reprojection complete.
# [INFO] Scaling the output data to conserve flux with factor 1.00
# [INFO] Flux scaling complete.
# [INFO] Reprojection process completed.
# [INFO] Pixel scale: 0.04 arcsec arcsec
# [INFO] Initial Resolution: 0.07 arcsec arcsec
# [INFO] Desired Resolution: 1.15 arcsec arcsec
# [INFO] Convolution kernel: 1.15 arcsec arcsec
# [INFO] Performing image convolution...
# [INFO] Image convolution complete.
# [INFO] Smoothing process completed.
# [INFO] Reprojecting the input image to match the template WCS...
# [INFO] Performing image reprojection...
# [INFO] Image reprojection complete.
# [INFO] Scaling the output data to conserve flux with factor 25.48
# [INFO] Flux scaling complete.
# [INFO] Reprojection process completed.
# [INFO] Pixel scale: 0.04 arcsec arcsec
# [INFO] Initial Resolution: 0.07 arcsec arcsec
# [INFO] Desired Resolution: 1.15 arcsec arcsec
# [INFO] Convolution kernel: 1.15 arcsec arcsec
# [INFO] Performing image convolution...
# [INFO] Image convolution complete.
# [INFO] Smoothing process completed.
# [INFO] Reprojecting the input image to match the template WCS...
# [INFO] Performing image reprojection...
# [INFO] Image reprojection complete.
# [INFO] Scaling the output data to conserve flux with factor 25.48
# [INFO] Flux scaling complete.
# [INFO] Reprojection process completed.
# [INFO] Pixel scale: 0.04 arcsec arcsec
# [INFO] Initial Resolution: 0.07 arcsec arcsec
# [INFO] Desired Resolution: 1.15 arcsec arcsec
# [INFO] Convolution kernel: 1.15 arcsec arcsec
# [INFO] Performing image convolution...
# [INFO] Image convolution complete.
# [INFO] Smoothing process completed.
# [INFO] Reprojecting the input image to match the template WCS...
# [INFO] Performing image reprojection...
# [INFO] Image reprojection complete.
# [INFO] Scaling the output data to conserve flux with factor 25.48
# [INFO] Flux scaling complete.
# [INFO] Reprojection process completed.
# [INFO] Remove NaN values around edge of image...
# [INFO] Pixel scale: 0.04 arcsec arcsec
# [INFO] Initial Resolution: 0.07 arcsec arcsec
# [INFO] Desired Resolution: 0.21 arcsec arcsec
# [INFO] Convolution kernel: 0.20 arcsec arcsec
# [INFO] Performing image convolution...
# [INFO] Image convolution complete.
# [INFO] Smoothing process completed.
# Run time: 2.6798140962918597 mins
# Writing: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst_contsub/ngc2835_hst_ha.fits
# Writing: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst_contsub/ngc2835_hst_ha_err.fits
# Writing: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst_contsub/ngc2835_hst_ha_as2.fits
# Writing: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst_contsub/ngc2835_hst_ha_err_as2.fits
# Writing: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst_contsub/ngc2835_muse_ha_as2.fits
# Writing: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc2835/hst_contsub/ngc2835_muse_contsub_ha_as2.fits

# %%
galaxy = 'ngc3351'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc3627'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc4254'
filters = ['f657n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc4303'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc4321'
filters = ['f657n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc4535'
filters = ['f657n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc5068'
filters = ['f658n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files

# %%
galaxy = 'ngc7496'
filters = ['f657n', 'f555w', 'f814w']
instruments = ['uvis', 'uvis', 'uvis']

pipeline = PyHSTHAContSub(galaxy, rootdir, filters, instruments) # Initialize the pipeline
pipeline.initial_pipeline() # Run the initial pipeline
pipeline.continuum_subtraction_pipeline_withMUSE() # Run the continuum subtraction pipeline with MUSE
pipeline.save_hdu_files(save_ha_only=True) # Save the HDU files
